# %%
import pandas as pd
import numpy as np
import turicreate
# Out:
# /home/akansh/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/akansh/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
songs = pd.read_csv('song_data.csv')
songs
# Out:
#                                           user_id             song_id  \
# 0        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4        b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# ...                                           ...                 ...
# 1116604  276e43ad698705e5011e5091f367d951b21246f5  SOWTYVO12AB0180BDA
# 1116605  276e43ad698705e5011e5091f367d951b21246f5  SOWZHOY12A6701F9FC
# 1116606  276e43ad698705e5011e5091f367d951b21246f5  SOXJOZW12A6701E90E
# 1116607  276e43ad698705e5011e5091f367d951b21246f5  SOXNKNC12A6701F7A8
# 1116608  276e43ad698705e5011e5091f367d951b21246f5  SOYRMVO12A6701D106
#
#          listen_count                                              title  \
# ...

# %%
songs_sf = turicreate.SFrame(songs)
songs_sf.head()
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %%
kw = songs_sf[songs_sf['artist'] == 'Kanye West']
ff = songs_sf[songs_sf['artist'] == 'Foo Fighters']
ts = songs_sf[songs_sf['artist'] == 'Taylor Swift']
lg = songs_sf[songs_sf['artist'] == 'Lady GaGa']

# %%
my_dict = {}
my_dict['Kanye West'] = len(kw['user_id'].unique())
my_dict['Foo Fighter'] = len(ff['user_id'].unique())
my_dict['Taylor Swift'] = len(ts['user_id'].unique())
my_dict['Lady GaGa'] = len(lg['user_id'].unique())
my_dict
# Out:
# {'Kanye West': 2522,
#  'Foo Fighter': 2055,
#  'Taylor Swift': 3246,
#  'Lady GaGa': 2928}

# %%
popular_artists = songs.groupby('artist')['listen_count'].sum()

# %%
print(np.argmax(popular_artists))
print(max(popular_artists))
# Out:
# Kings Of Leon
# 43218

# %%
print(np.argmin(popular_artists))
print(min(popular_artists))
# Out:
# William Tabbert
# 14
