# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import turicreate
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('home_data.csv')
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
sf = turicreate.SFrame('home_data.sframe')
sf
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
sf.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
turicreate.show(sf['zipcode'],sf['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %%
df[df['zipcode'] == 98039]['price'].mean()
# Out:
# 2160606.6

# %%
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
plt.scatter(df['sqft_living'],df['price'])
plt.show()

# %% [markdown]
# # Filtering

# %%
res = list(filter(lambda x: 2000<x<4000,df['sqft_living']))
len(res)/len(df['sqft_living'])
# Out:
# 0.4215518437977143

# %% [markdown]
# # Regression Model

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house				
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
advanced_features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'zipcode',
#  'condition',
#  'grade',
#  'waterfront',
#  'view',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
df[advanced_features]
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  zipcode  condition  \
# 0             3       1.00         1180      5650     1.0    98178          3
# 1             3       2.25         2570      7242     2.0    98125          3
# 2             2       1.00          770     10000     1.0    98028          3
# 3             4       3.00         1960      5000     1.0    98136          5
# 4             3       2.00         1680      8080     1.0    98074          3
# ...         ...        ...          ...       ...     ...      ...        ...
# 21608         3       2.50         1530      1131     3.0    98103          3
# 21609         4       2.50         2310      5813     2.0    98146          3
# 21610         2       0.75         1020      1350     2.0    98144          3
# 21611         3       2.50         1600      2388     2.0    98027          3
# 21612         2       0.75         1020      1076     2.0    98144          3
#
# ...

# %% [markdown]
# ## Regression Model on Advanced Features

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[advanced_features],df['price'],random_state=0,test_size = 0.2)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((17290, 18), (4323, 18), (17290,), (4323,))

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
model.score(X_test,Y_test)
# Out:
# 0.694931000141797

# %%
y_pred = model.predict(X_test)

# %%
rmse_advanced = np.mean((y_pred - Y_test) ** 2)
np.sqrt(rmse_advanced)
# Out:
# 190473.37570967615

# %% [markdown]
# ## Regression Model on My Features

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[my_features],df['price'],random_state=0,test_size = 0.2)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((17290, 6), (4323, 6), (17290,), (4323,))

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
model.score(X_test,Y_test)
# Out:
# 0.499359281311759

# %%
y_pred = model.predict(X_test)
rmse_advanced = np.mean((y_pred - Y_test) ** 2)
np.sqrt(rmse_advanced)
# Out:
# 244004.7744310415

# %%
 244004.7744310415 - 190473.37570967615
# Out:
# 53531.398721365345
